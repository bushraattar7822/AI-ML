# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# #load dataset
# df = pd.read_csv("healthcare_patient_visits.csv")
# print(df.head())

# #average  treatment cost by condition
# avg_cost_by_condition = df.groupby("Condition")["TreatmentCost"].mean()
# print("Average Treatment Cost by Condition:")
# print(avg_cost_by_condition)

#patients count by city
patients_by_city = df["City"].value_counts()
print("Patients Count by City:")
print(patients_by_city)


# #average bp by condition
# df[['BP_sys', 'BP_dia']] = df['BP'].str.split('/', expand=True).astype(float)
# avg_BP_by_condition = df.groupby("Condition")["BP_sys"].mean()
# print(avg_BP_by_condition)

# bar chart
avg_cost_by_condition = df.groupby("Condition")["TreatmentCost"].mean()
plt.figure(figsize=(8,5))
avg_cost_by_condition.plot(kind='bar')
plt.title("Average Treatment Cost by Condition")
plt.xlabel("Condition")
plt.ylabel("Average Treatment Cost")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#histogram
plt.figure(figsize=(8,5))
plt.hist(df["Age"], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# boxplot
plt.figure(figsize=(8,5))
df.boxplot(column="TreatmentCost", by="SmokingStatus")
plt.title("Treatment Cost by Smoking Status")
plt.suptitle("")  # removes default pandas boxplot extra title
plt.xlabel("Smoking Status")
plt.ylabel("Treatment Cost")
plt.show()
# Out:
# Patients Count by City:
# City
# Pune         30
# Belagavi     27
# Hubballi     25
# Dharwad      24
# Mumbai       22
# Bengaluru    22
# Name: count, dtype: int64
